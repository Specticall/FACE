# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd  
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import PIL
from pathlib import Path
import os
import tensorflow as tf
from tensorflow.keras.layers import Dense,Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.utils import class_weight
import numpy as np
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # Load & Preprocess Data

# %%
data_dir = "data/train"#directory of the  train data
test_dir = "data/test"#directory of the  test data

height,width=180,180#Size of the image
batch_size=32
train_dataset =tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(height,width),# resize images after they are read from folder
  batch_size=batch_size)#Size of the batches of data to load at a time
# Out:
# Found 8386 files belonging to 7 classes.
# Using 6709 files for training.

# %%
val_dataset= tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(height,width),
  batch_size=batch_size)
# Out:
# Found 8386 files belonging to 7 classes.
# Using 1677 files for validation.

# %%
test_dataset=tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,#directory of the  test data
    shuffle = True,
    seed=123,
    image_size =(height,width),
    batch_size =batch_size  
)
# Out:
# Found 2201 files belonging to 7 classes.

# %%
class_names=train_dataset.class_names
print(class_names)
# Out:
# ['Acne and Rosacea Photos', 'Actinic Keratosis Basal Cell Carcinoma and other Malignant Lesions', 'Eczema Photos', 'Psoriasis pictures Lichen Planus and related diseases', 'Seborrheic Keratoses and other Benign Tumors', 'Tinea Ringworm Candidiasis and other Fungal Infections', 'Warts Molluscum and other Viral Infections']

# %%
plt.figure(figsize = (10,10))#setting the size images in plot only
for images, labels in train_dataset.take(1):#looping through the dataset
   for i in range(9):
     ax = plt.subplot(3,3,i+1)
     plt.imshow(images[i].numpy().astype("uint8"))
     plt.title(class_names[labels[i]],fontsize = 10)
     plt.subplots_adjust(right =1.5)   
     plt.axis("off")

# %%
location = Path('data/train')
array = []
for folders in location.glob("*"):
    row = {}
    row["disease"] = folders.name.replace("Photos", "")
    list = os.listdir(folders) 
    countFiles = len(list)
    row["count"] =countFiles
    array.append(row)  
df=pd.DataFrame(array) 
print(df)
# Out:
#                                              disease  count
# 0                                  Acne and Rosacea     840
# 1  Actinic Keratosis Basal Cell Carcinoma and oth...   1149
# 2                                            Eczema    1235
# 3  Psoriasis pictures Lichen Planus and related d...   1405
# 4       Seborrheic Keratoses and other Benign Tumors   1371
# 5  Tinea Ringworm Candidiasis and other Fungal In...   1300
# 6         Warts Molluscum and other Viral Infections   1086

# %%
# Step 1: Plotting a Bar Chart
plt.figure(figsize=(10, 6))

# Step 2: Create the bar chart
plt.bar(df["disease"], df["count"], color='skyblue')

# Step 3: Adding labels and title
plt.xlabel('Disease Class', fontsize=12)
plt.ylabel('Number of Images', fontsize=12)
plt.title('Distribution of Diseases in Training Data', fontsize=14)

# Step 4: Rotate the x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Step 5: Show the plot
plt.tight_layout()  # Adjust layout to avoid clipping
plt.show()

# %% [markdown]
# # Load Model + Add Layers

# %%
model= Sequential()

vgg_model= tf.keras.applications.VGG16(include_top=False,
                   input_shape=(180,180,3),
                   pooling='avg',classes=7,
                   weights='imagenet')

for layer in vgg_model.layers:
        layer.trainable=True#freezing layers of the resnet model

# %%
model.add(vgg_model)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))#output layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,110,471 (57.64 MB)
#  Trainable params: 395,783 (1.51 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
# Compute class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(class_names),
    y=class_names
)

class_weights_dict = dict(enumerate(class_weights))

# %% [markdown]
# # Training

# %%
epochs=100
history=model.fit(train_dataset,validation_data=val_dataset,epochs=epochs,class_weight=class_weights_dict,callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 184s 869ms/step - accuracy: 0.1997 - loss: 7.4365 - val_accuracy: 0.3298 - val_loss: 4.9956
# Epoch 2/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 187s 892ms/step - accuracy: 0.2890 - loss: 5.1243 - val_accuracy: 0.3578 - val_loss: 4.7064
# Epoch 3/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 907ms/step - accuracy: 0.3534 - loss: 4.6895 - val_accuracy: 0.3936 - val_loss: 4.4693
# Epoch 4/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.3962 - loss: 4.4162 - val_accuracy: 0.4114 - val_loss: 4.2361
# Epoch 5/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 901ms/step - accuracy: 0.4366 - loss: 4.1323 - val_accuracy: 0.4359 - val_loss: 4.0259
# Epoch 6/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.4647 - loss: 3.8932 - val_accuracy: 0.4484 - val_loss: 3.8261
# Epoch 7/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 901ms/step - accuracy: 0.5013 - loss: 3.6429 - val_accuracy: 0.4603 - val_loss: 3.6500
# Epoch 8/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.5165 - loss: 3.4430 - val_accuracy: 0.4603 - val_loss: 3.4909
# Epoch 9/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 904ms/step - accuracy: 0.5374 - loss: 3.2650 - val_accuracy: 0.4753 - val_loss: 3.3373
# Epoch 10/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 904ms/step - accuracy: 0.5742 - loss: 3.0622 - val_accuracy: 0.4794 - val_loss: 3.2071
# Epoch 11/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.5910 - loss: 2.9056 - val_accuracy: 0.4764 - val_loss: 3.0762
# Epoch 12/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.5986 - loss: 2.7574 - val_accuracy: 0.4860 - val_loss: 2.9694
# Epoch 13/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 901ms/step - accuracy: 0.6300 - loss: 2.6111 - val_accuracy: 0.4943 - val_loss: 2.8571
# Epoch 14/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.6425 - loss: 2.4840 - val_accuracy: 0.4902 - val_loss: 2.7682
# Epoch 15/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 899ms/step - accuracy: 0.6605 - loss: 2.3547 - val_accuracy: 0.4967 - val_loss: 2.6910
# Epoch 16/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 904ms/step - accuracy: 0.6689 - loss: 2.2498 - val_accuracy: 0.5033 - val_loss: 2.6209
# Epoch 17/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 192s 913ms/step - accuracy: 0.6911 - loss: 2.1437 - val_accuracy: 0.5086 - val_loss: 2.5442
# Epoch 18/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 904ms/step - accuracy: 0.6952 - loss: 2.0549 - val_accuracy: 0.5086 - val_loss: 2.4749
# Epoch 19/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 901ms/step - accuracy: 0.7218 - loss: 1.9555 - val_accuracy: 0.5116 - val_loss: 2.4178
# Epoch 20/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 903ms/step - accuracy: 0.7169 - loss: 1.8862 - val_accuracy: 0.5230 - val_loss: 2.3600
# Epoch 21/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 901ms/step - accuracy: 0.7437 - loss: 1.7869 - val_accuracy: 0.5253 - val_loss: 2.3320
# Epoch 22/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.7481 - loss: 1.7265 - val_accuracy: 0.5182 - val_loss: 2.2858
# Epoch 23/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.7718 - loss: 1.6404 - val_accuracy: 0.5265 - val_loss: 2.2395
# Epoch 24/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.7803 - loss: 1.5839 - val_accuracy: 0.5331 - val_loss: 2.2034
# Epoch 25/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 907ms/step - accuracy: 0.7843 - loss: 1.5263 - val_accuracy: 0.5426 - val_loss: 2.1763
# Epoch 26/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.7948 - loss: 1.4721 - val_accuracy: 0.5379 - val_loss: 2.1403
# Epoch 27/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.8095 - loss: 1.4175 - val_accuracy: 0.5414 - val_loss: 2.1081
# Epoch 28/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 899ms/step - accuracy: 0.8182 - loss: 1.3537 - val_accuracy: 0.5474 - val_loss: 2.1047
# Epoch 29/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 899ms/step - accuracy: 0.8267 - loss: 1.2962 - val_accuracy: 0.5474 - val_loss: 2.0783
# Epoch 30/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.8367 - loss: 1.2525 - val_accuracy: 0.5558 - val_loss: 2.0520
# Epoch 31/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.8387 - loss: 1.2125 - val_accuracy: 0.5498 - val_loss: 2.0324
# Epoch 32/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.8399 - loss: 1.1800 - val_accuracy: 0.5498 - val_loss: 2.0326
# Epoch 33/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.8570 - loss: 1.1178 - val_accuracy: 0.5403 - val_loss: 2.0060
# Epoch 34/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.8653 - loss: 1.0795 - val_accuracy: 0.5492 - val_loss: 1.9790
# Epoch 35/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 900ms/step - accuracy: 0.8725 - loss: 1.0393 - val_accuracy: 0.5569 - val_loss: 1.9811
# Epoch 36/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 188s 898ms/step - accuracy: 0.8827 - loss: 1.0051 - val_accuracy: 0.5468 - val_loss: 1.9773
# Epoch 37/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 192s 914ms/step - accuracy: 0.8873 - loss: 0.9744 - val_accuracy: 0.5635 - val_loss: 1.9660
# Epoch 38/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 194s 922ms/step - accuracy: 0.8944 - loss: 0.9336 - val_accuracy: 0.5569 - val_loss: 1.9913
# Epoch 39/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 190s 906ms/step - accuracy: 0.8988 - loss: 0.9021 - val_accuracy: 0.5558 - val_loss: 1.9929
# Epoch 40/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.9015 - loss: 0.8678 - val_accuracy: 0.5534 - val_loss: 1.9749
# Epoch 41/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 902ms/step - accuracy: 0.9115 - loss: 0.8323 - val_accuracy: 0.5552 - val_loss: 1.9753
# Epoch 42/100
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 189s 901ms/step - accuracy: 0.9218 - loss: 0.7935 - val_accuracy: 0.5605 - val_loss: 1.9672

# %% [markdown]
# # Model Evaluation

# %%
#plotting the learning curves training and validation accuracy/loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(8, 7))
plt.subplot(2, 1, 1)
plt.axis(ymin=0.4,ymax=1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
model.save("./vgg_v6.keras");

# %%
#testing model accuracy with the testing set(unbiased)
score =model.evaluate(test_dataset)
print('Test accuracy:', score[1])
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 46s 664ms/step - accuracy: 0.5826 - loss: 1.8945
# Test accuracy: 0.5792821645736694

# %%
#predicting multiple images
def predict_image(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

plt.figure(figsize=(8, 8))
for images, labels in test_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class, confidence = predict_image(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        plt.subplots_adjust(right =2,top=1.5)
        plt.title(f"Act: {actual_class},\n Predi: {predicted_class}.\n Conf: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
